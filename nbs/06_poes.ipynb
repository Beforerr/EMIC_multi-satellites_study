# %% [markdown]
# ## POES observations of proton precipitation
#
# Overview of the POES from THEMIS website
# <!-- ![](http://themis.ssl.berkeley.edu/themisdata/overplots/2021/04/17/noaa18_20210417_0024.png) -->
# <!-- ![](http://themis.ssl.berkeley.edu/themisdata/overplots/2021/04/17/noaa19_20210417_0024.png) -->
#
# <div float="left">
#   <img src="http://themis.ssl.berkeley.edu/themisdata/overplots/2021/04/17/noaa15_20210417_0024.png" width="45%">
#   <img src="http://themis.ssl.berkeley.edu/themisdata/overplots/2021/04/17/noaa19_20210417_0024.png" width="45%">
# </div>

# %%
# %load_ext autoreload
# %autoreload 2
import logging
from elfin_emics.poes import plot_poes_mep_pro

logger = logging.getLogger()

# %%
# | code-summary: POES observations of proton precipitation
# | layout-ncol: 3
# | column: page
logger.disabled = True

probe = "noaa15"
time_slices = [
    ["2021-04-17 01:15:00", "2021-04-17 01:20:00"],
    ["2021-04-17 02:57:00", "2021-04-17 03:03:00"],
    ["2021-04-17 04:38:00", "2021-04-17 04:44:00"],
    # added figures in response to reviewers' comments
    ["2021-04-17 06:20:00", "2021-04-17 06:26:00"],
]

[
    plot_poes_mep_pro(probe=probe, trange=time_slice, save=True)
    for time_slice in time_slices
]

probe = "noaa19"
time_slices = [
    ["2021-04-17 01:47:00", "2021-04-17 01:52:00"],
    ["2021-04-17 03:30:00", "2021-04-17 03:36:00"],
    ["2021-04-17 05:12:00", "2021-04-17 05:18:00"],
    # added figures in response to reviewers' comments
    ["2021-04-17 06:54:00", "2021-04-17 07:00:00"],
]

[
    plot_poes_mep_pro(probe=probe, trange=time_slice, save=True)
    for time_slice in time_slices
]

logger.disabled = False
# Out:
# 08-Oct-24 13:56:56: /Users/zijin/projects/elfin_emic/.pixi/envs/default/lib/python3.10/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
#
# 08-Oct-24 13:56:56: /Users/zijin/projects/elfin_emic/.pixi/envs/default/lib/python3.10/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)
# Figure(nrows=2, ncols=1, refaspect=2, refwidth=5.0)

# %% [markdown]
# POES observations of proton precipitation confirms the L-shell localization of EMIC generation region between L~4.5 and 6. At L>6 POES shows strong curvature scattering of protons indicating on isotropic equatorial distribution and no EMIC wave generation"
